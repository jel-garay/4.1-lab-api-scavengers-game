# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
# Out:
# False

# %%
github = os.getenv("token")

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %%
with open('../password.txt', 'r') as file:
    pass_=file.read()

# %%
import requests as req

# %%
HEADER={'Authorization': 'token ' + pass_}

# %%
url_1='https://api.github.com/repos/Ironhack-Data-Madrid-Enero-2023/apuntes_clase'

# %%
result_git=req.get(url)  # nos ha dado 200 así que OK

result_git
# Out:
# <Response [200]>

# %%
result_git.json()
# Out:
# {'id': 588107458,
#  'node_id': 'R_kgDOIw3Owg',
#  'name': 'apuntes_clase',
#  'full_name': 'Ironhack-Data-Madrid-Enero-2023/apuntes_clase',
#  'private': False,
#  'owner': {'login': 'Ironhack-Data-Madrid-Enero-2023',
#   'id': 122526190,
#   'node_id': 'O_kgDOB02Z7g',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/122526190?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Ironhack-Data-Madrid-Enero-2023',
#   'html_url': 'https://github.com/Ironhack-Data-Madrid-Enero-2023',
#   'followers_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Enero-2023/followers',
#   'following_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Enero-2023/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Enero-2023/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Enero-2023/starred{/owner}{/repo}',
# ...

# %%
url='https://api.github.com/repos/Ironhack-Data-Madrid-Enero-2023/apuntes_clase/forks' #cogemos del jason las que queremos que son las que están en forks

# %%
result_git=req.get(url)  # nos ha dado 200 así que OK

result_git
# Out:
# <Response [200]>

# %%
result_git.json()
# Out:
# [{'id': 595050388,
#   'node_id': 'R_kgDOI3e_lA',
#   'name': 'apuntes_clase',
#   'full_name': 'CharlyKill7/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'CharlyKill7',
#    'id': 121037629,
#    'node_id': 'U_kgDOBzbjPQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121037629?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CharlyKill7',
#    'html_url': 'https://github.com/CharlyKill7',
#    'followers_url': 'https://api.github.com/users/CharlyKill7/followers',
#    'following_url': 'https://api.github.com/users/CharlyKill7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CharlyKill7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CharlyKill7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CharlyKill7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/CharlyKill7/orgs',
# ...

# %%
language_atr = []                                  # hacemos una lista vacia y luego la iteramos por el jason que es donde está language.

for fork in result_git.json():
    language_atr.append(fork['language'])

print(language_atr)
# Out:
# [None, None, 'Jupyter Notebook', None, 'Jupyter Notebook', None, None, None, None, None, None, 'Jupyter Notebook', None, None, 'Jupyter Notebook']
